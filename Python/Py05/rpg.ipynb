# %%
class Character:
    def __init__(self, name, level, hp, attack, defense):
        self.name = name
        self.level = level
        self.hp = hp
        self.attack = attack
        self.depense = defense

    def take_damage(self, damage):
        real_damage = damage - self.depense
        if real_damage > 0:
            return

        self.hp -= real_damage

    def attack_target(self, target):
        damage = random.randint(1, self.attack)
        target.take_damage(damage)

# %%
class Player(Character):
    LEVEL_UP_EXP_REQUIRED = 50
    ATK_INCREASE = 10
    DEF_INCREASE = 5
    LEVEL_INCREASE = 1
    
    def __init__(self, name):
        super().__init__(name, level=1, hp=100, attack=25, defense=5)
        self.experience = 0

    
    def gaim_experience(self, amount):
        self.experience += amount
        if self.experience >= LEVEL_UP_EXP_REQUIRED:
            self.level_up()


    def level_up(self):
        self.level += LEVEL_INCREASE
        self.attack += ATK_INCREASE
        self.defense += DEF_INCREASE
        self.experience -= LEVEL_UP_EXP_REQUIRED

# %%
class Monst(Character):
    def __init__(self, name, level):
         super().__init__(name, level=1, hp=100, attack=25, defense=5)
# Out:
#   Cell In[12], line 1
#     class Monst(Charactor):
#                            ^
# SyntaxError: incomplete input
